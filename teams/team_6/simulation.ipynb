# %%
ability_team = "2"
task_team = "2"
abilities_difficulty = "hard"
task_difficulty = "hard"
num_abilities = "3"
num_members = "20"

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file_name = f"./data/{ability_team}_{abilities_difficulty}_{task_team}_{task_difficulty}_{num_abilities}_{num_members}.npy"
data = np.load(file_name)

data
# Out:
# array([  9,  21,  28,  31,  34,  35,  36,  37,  39,  39,  39,  40,  49,
#         58,  65,  67,  68,  68,  69,  70,  71,  73,  74,  76,  76,  77,
#         78,  78,  78,  79,  80,  90, 100, 108, 109, 111, 112, 113, 113,
#        115, 116, 117, 117, 117, 118, 119, 119, 119, 120, 128, 137, 143,
#        146, 148, 151, 152, 153, 154, 155, 156, 156, 158, 159, 160, 172,
#        180, 182, 185, 186, 187, 188, 190, 191, 193, 194, 194, 195, 196,
#        196, 197, 197, 198, 199, 200, 211, 218, 224, 228, 230, 231, 232,
#        233, 234, 235, 237, 237, 237, 238, 238, 238, 239, 240, 250, 259,
#        266, 270, 271, 272, 272, 274, 275, 276, 277, 277, 278, 278, 279,
#        280, 290, 300, 305, 308, 308, 310, 311, 313, 314, 314, 315, 316,
#        317, 318, 318, 318, 319, 320, 331, 340, 343, 346, 347, 349, 350,
#        351, 352, 353, 354, 355, 356, 357])

# %%
plt.plot(data)
